# %%
import pandas as pd   # Importing pandas

movie = pd.read_csv("movies.csv")   # Reading CSV file
movie.head()   # Displaying first 5 rows
# Out:
# C:\Users\veeru\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
for i in movie.columns:   # printing all columns
    print(i)

movie.shape  # Displaying rows and columns
# Out:
# adult
# belongs_to_collection
# budget
# genres
# homepage
# id
# imdb_id
# original_language
# original_title
# overview
# popularity
# poster_path
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# video
# vote_average
# vote_count
# (45466, 24)

# %%
movie.describe()   # Statistic of the dataframe
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
movie["original_language"].value_counts()   # Count of languages
# Out:
# en      32269
# fr       2438
# it       1529
# ja       1350
# de       1080
#         ...
# cy          1
# sm          1
# fy          1
# zu          1
# 68.0        1
# Name: original_language, Length: 92, dtype: int64

# %%
import matplotlib.pyplot as plt   # Importing matplotlib

plt.bar(list(movie["original_language"].value_counts()[0:5].keys()), list(movie["original_language"].value_counts()[0:5]), color=["red", "blue", "orange", "green", "yellow"])
plt.title("Orginal Languages")
plt.xlabel("Languages")
plt.ylabel("Num of Movies")
plt.show()   # Graph for num of movies in first 5 languages

# %%
plt.hist(movie["vote_average"], color=["m"])   #voting for the movies
plt.title("Voting")
plt.xlabel("Rating")
plt.ylabel("Num of movies")
plt.show()

# %%
high_rated_movies = movie[movie["vote_average"]>8]   # Movies have rating more than 8
print(high_rated_movies.shape)   # Rows and columns have rating more than 8
high_rated_movies.head()   # First 5 rows have rating more than 8
# Out:
# (1130, 24)
#      adult                              belongs_to_collection    budget  \
# 46   False                                                NaN  33000000
# 49   False                                                NaN   6000000
# 109  False                                                NaN   1300000
# 186  False                                                NaN         0
# 256  False  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
#
#                                                 genres  \
# 46   [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 109  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 186  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 256  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                               homepage     id    imdb_id  \
# 46                          http://www.sevenmovie.com/    807  tt0114369
# ...

# %%
top_5 = movie.sort_values(by="vote_average", ascending=False).head()
top_5   #top 5 movies have top rating
# Out:
#        adult belongs_to_collection  budget  \
# 21642  False                   NaN       0
# 15710  False                   NaN       0
# 22396  False                   NaN       0
# 22395  False                   NaN       0
# 35343  False                   NaN  300000
#
#                                                   genres  \
# 21642                [{'id': 99, 'name': 'Documentary'}]
# 15710                [{'id': 99, 'name': 'Documentary'}]
# 22396                [{'id': 99, 'name': 'Documentary'}]
# 22395                [{'id': 99, 'name': 'Documentary'}]
# 35343  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
#
#                                   homepage      id    imdb_id  \
# 21642                                  NaN  320849  tt0886500
# 15710                                  NaN   96451  tt1587373
# 22396                                  NaN   72123  tt1341746
# 22395  http://www.marvinhamlischmovie.com/  230864  tt3011874
# ...

# %%
top_5_revenue = movie.sort_values("revenue", ascending=False).head()
top_5_revenue   #top 5 movies have top revenue
# Out:
#        adult                              belongs_to_collection     budget  \
# 14551  False  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 26555  False  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 1639   False                                                NaN  200000000
# 17818  False  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 25084  False  {'id': 328, 'name': 'Jurassic Park Collection'...  150000000
#
#                                                   genres  \
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 26555  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1639   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17818  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 25084  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 14551                        http://www.avatarmovie.com/   19995  tt0499549
# ...

# %%
plt.hist(movie["runtime"], color="c")
plt.show()   # To check how long the num of movies were in threaters

# %%
movie["status"].value_counts()   # To check the status of the movies
# Out:
# Released           45014
# Rumored              230
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
plt.hist(movie["vote_count"], color="g")
plt.show()    # To check voting of movies
