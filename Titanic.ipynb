# %%
import pandas as pd   #importing pandas

df = pd.read_csv("titanic.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
print(df.shape)   # Displaying rows and columns
print(df.info())   # Information in dataframe
df.describe()   # Statistics of dataset
# Out:
# (1309, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB
# None
#             pclass     survived          age        sibsp        parch  \
# ...

# %%
print(df.isna().sum(), "\n")   # checking the missing values
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
from sklearn import preprocessing   #importing preprocessing

label_encoder = preprocessing.LabelEncoder()   #to convert sex data to numeric
df[["sex"]] = label_encoder.fit_transform(df["sex"])
df["sex"].value_counts()
# Out:
# 1    843
# 0    466
# Name: sex, dtype: int64

# %%
df  = df.drop(["name", "cabin", "fare", "home.dest"], axis = 1)   # Droping unnecessory data from dataframe
df
# Out:
#       pclass  survived  sex    age  sibsp  parch  ticket embarked boat   body
# 0          1         1    0  29.00      0      0   24160        S    2    NaN
# 1          1         1    1   0.92      1      2  113781        S   11    NaN
# 2          1         0    0   2.00      1      2  113781        S  NaN    NaN
# 3          1         0    1  30.00      1      2  113781        S  NaN  135.0
# 4          1         0    0  25.00      1      2  113781        S  NaN    NaN
# ...      ...       ...  ...    ...    ...    ...     ...      ...  ...    ...
# 1304       3         0    0  14.50      1      0    2665        C  NaN  328.0
# 1305       3         0    0    NaN      1      0    2665        C  NaN    NaN
# 1306       3         0    1  26.50      0      0    2656        C  NaN  304.0
# 1307       3         0    1  27.00      0      0    2670        C  NaN    NaN
# 1308       3         0    1  29.00      0      0  315082        S  NaN    NaN
#
# [1309 rows x 10 columns]

# %%
df["age"] = df["age"].fillna(df["age"].mean())   #replacing missing values with mean
df
# Out:
#       pclass  survived  sex        age  sibsp  parch  ticket embarked boat  \
# 0          1         1    0  29.000000      0      0   24160        S    2
# 1          1         1    1   0.920000      1      2  113781        S   11
# 2          1         0    0   2.000000      1      2  113781        S  NaN
# 3          1         0    1  30.000000      1      2  113781        S  NaN
# 4          1         0    0  25.000000      1      2  113781        S  NaN
# ...      ...       ...  ...        ...    ...    ...     ...      ...  ...
# 1304       3         0    0  14.500000      1      0    2665        C  NaN
# 1305       3         0    0  29.881138      1      0    2665        C  NaN
# 1306       3         0    1  26.500000      0      0    2656        C  NaN
# 1307       3         0    1  27.000000      0      0    2670        C  NaN
# 1308       3         0    1  29.000000      0      0  315082        S  NaN
#
#        body
# 0       NaN
# 1       NaN
# 2       NaN
# 3     135.0
# ...

# %%
df["boat"] = df["boat"].fillna(df["boat"].mode()[0])   #replacing missing values with mode
df
# Out:
#       pclass  survived  sex        age  sibsp  parch  ticket embarked boat  \
# 0          1         1    0  29.000000      0      0   24160        S    2
# 1          1         1    1   0.920000      1      2  113781        S   11
# 2          1         0    0   2.000000      1      2  113781        S   13
# 3          1         0    1  30.000000      1      2  113781        S   13
# 4          1         0    0  25.000000      1      2  113781        S   13
# ...      ...       ...  ...        ...    ...    ...     ...      ...  ...
# 1304       3         0    0  14.500000      1      0    2665        C   13
# 1305       3         0    0  29.881138      1      0    2665        C   13
# 1306       3         0    1  26.500000      0      0    2656        C   13
# 1307       3         0    1  27.000000      0      0    2670        C   13
# 1308       3         0    1  29.000000      0      0  315082        S   13
#
#        body
# 0       NaN
# 1       NaN
# 2       NaN
# 3     135.0
# ...

# %%
df["body"] = df["body"].fillna(df["body"].median())   #replacing missing values with median
df
# Out:
#       pclass  survived  sex        age  sibsp  parch  ticket embarked boat  \
# 0          1         1    0  29.000000      0      0   24160        S    2
# 1          1         1    1   0.920000      1      2  113781        S   11
# 2          1         0    0   2.000000      1      2  113781        S   13
# 3          1         0    1  30.000000      1      2  113781        S   13
# 4          1         0    0  25.000000      1      2  113781        S   13
# ...      ...       ...  ...        ...    ...    ...     ...      ...  ...
# 1304       3         0    0  14.500000      1      0    2665        C   13
# 1305       3         0    0  29.881138      1      0    2665        C   13
# 1306       3         0    1  26.500000      0      0    2656        C   13
# 1307       3         0    1  27.000000      0      0    2670        C   13
# 1308       3         0    1  29.000000      0      0  315082        S   13
#
#        body
# 0     155.0
# 1     155.0
# 2     155.0
# 3     135.0
# ...

# %%
g = df.groupby("survived")   #groping the survived data
g["embarked"].value_counts()   #counting the embarked based on survived
# Out:
# survived  embarked
# 0         S           610
#           C           120
#           Q            79
# 1         S           304
#           C           150
#           Q            44
# Name: embarked, dtype: int64

# %%
df["embarked"] = df["embarked"].fillna(value = "s")   #replacing missing values with s
df
# Out:
#       pclass  survived  sex        age  sibsp  parch  ticket embarked boat  \
# 0          1         1    0  29.000000      0      0   24160        S    2
# 1          1         1    1   0.920000      1      2  113781        S   11
# 2          1         0    0   2.000000      1      2  113781        S   13
# 3          1         0    1  30.000000      1      2  113781        S   13
# 4          1         0    0  25.000000      1      2  113781        S   13
# ...      ...       ...  ...        ...    ...    ...     ...      ...  ...
# 1304       3         0    0  14.500000      1      0    2665        C   13
# 1305       3         0    0  29.881138      1      0    2665        C   13
# 1306       3         0    1  26.500000      0      0    2656        C   13
# 1307       3         0    1  27.000000      0      0    2670        C   13
# 1308       3         0    1  29.000000      0      0  315082        S   13
#
#        body
# 0     155.0
# 1     155.0
# 2     155.0
# 3     135.0
# ...

# %%
df["embarked"] = label_encoder.fit_transform(df["embarked"])   #to convert embarked data to numeric
df["embarked"].value_counts()
# Out:
# 2    914
# 0    270
# 1    123
# 3      2
# Name: embarked, dtype: int64

# %%
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

from matplotlib import pyplot as plt
import seaborn as sns
sns.countplot(df["embarked"], hue = df["survived"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.corr()   #pairwise correlation of all columns in the dataframe
# Out:
#             pclass  survived       sex       age     sibsp     parch  \
# pclass    1.000000 -0.312469  0.124617 -0.366371  0.060832  0.018322
# survived -0.312469  1.000000 -0.528693 -0.050198 -0.027825  0.082660
# sex       0.124617 -0.528693  1.000000  0.057397 -0.109609 -0.213125
# age      -0.366371 -0.050198  0.057397  1.000000 -0.190747 -0.130872
# sibsp     0.060832 -0.027825 -0.109609 -0.190747  1.000000  0.373587
# parch     0.018322  0.082660 -0.213125 -0.130872  0.373587  1.000000
# embarked  0.182154 -0.172526  0.095215 -0.068091  0.064519  0.043835
# body     -0.013432 -0.014250  0.008469  0.028547 -0.028519  0.012973
#
#           embarked      body
# pclass    0.182154 -0.013432
# survived -0.172526 -0.014250
# sex       0.095215  0.008469
# age      -0.068091  0.028547
# sibsp     0.064519 -0.028519
# parch     0.043835  0.012973
# embarked  1.000000 -0.004299
# body     -0.004299  1.000000

# %%
df.plot(x = "embarked", y = ["sibsp", "parch"], kind = "bar")   #ploting graph between sibsp and parch
plt.title("bar graph")
# Out:
# Text(0.5, 1.0, 'bar graph')

# %%
sns.heatmap(df.corr())   #representing various shades of the same colour for each value to be plotted
# Out:
# <AxesSubplot:>

# %%
df["family"] = df["sibsp"] + df["parch"] + 1   #grouping sibsp and parch as a sigle column
df = df.drop(["sibsp", "parch", "ticket", "boat"], axis = 1)   #droping the unwanted data
df
# Out:
#       pclass  survived  sex        age  embarked   body  family
# 0          1         1    0  29.000000         2  155.0       1
# 1          1         1    1   0.920000         2  155.0       4
# 2          1         0    0   2.000000         2  155.0       4
# 3          1         0    1  30.000000         2  135.0       4
# 4          1         0    0  25.000000         2  155.0       4
# ...      ...       ...  ...        ...       ...    ...     ...
# 1304       3         0    0  14.500000         0  328.0       2
# 1305       3         0    0  29.881138         0  155.0       2
# 1306       3         0    1  26.500000         0  304.0       1
# 1307       3         0    1  27.000000         0  155.0       1
# 1308       3         0    1  29.000000         2  155.0       1
#
# [1309 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# Segregating labels into separate variable
x = df.drop("survived", axis = 1).values
y = df["survived"].values

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=6)

# %%
from sklearn.preprocessing import StandardScaler   #importing StandardScaler

sc = StandardScaler()   # Assigning StandardScaler to sc
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression   # import LogisticRegression

log_reg = LogisticRegression()   # Assigning LogisticRegression() to log_reg
log_reg.fit(x_train, y_train)   #fitting log_reg to the train the model
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score   # import accuracy_score

predict = log_reg.predict(x_test)   #predict instances from the test set

# finding score for logreg model
print("accuracy of logistic regression classifert: ", log_reg.score(x_test, y_test))

accuracy_score(y_test, predict)
# Out:
# accuracy of logistic regression classifert:  0.7824427480916031
# 0.7824427480916031

# %%
from sklearn.metrics import confusion_matrix # import confusion_matrix

predict = log_reg.predict(x_test)   #predict instances from the test set

confusion_matrix(y_test, predict)
# Out:
# array([[134,  18],
#        [ 39,  71]], dtype=int64)
